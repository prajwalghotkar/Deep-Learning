# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
w=tf.Variable([2.0])  
b=tf.Variable([1.0]) 
x=tf.compat.v1.placeholder(tf.float32)
# Out:
# WARNING:tensorflow:From C:\Users\pmgho\AppData\Local\Temp\ipykernel_15608\519959875.py:2: The name tf.disable_eager_execution is deprecated. Please use tf.compat.v1.disable_eager_execution instead.

# %%
linear_model=w*x + b  
init = tf.compat.v1.global_variables_initializer()

# %%
#initialize the session
sess = tf.compat.v1.Session()
sess.run(init)

# %%
print("predicted output when input is 0")
print(sess.run(linear_model,{x:[0]})) # output is 1 when input is 0
# Out:
# predicted output when input is 0
# [1.]

# %%
print("predicted output when input is 0")
print(sess.run(linear_model,{x:[0,0,0]})) # output is 1 when input is 0
# Out:
# predicted output when input is 0
# [1. 1. 1.]

# %%
print(sess.run(linear_model,{x:[1,2,3,4]}))
# Out:
# [3. 5. 7. 9.]
