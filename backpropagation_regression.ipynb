# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa', 'profile_score', 'lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):

  np.random.seed(3)
  parameters = {}
  L = len(layer_dims)

  for l in range(1, L):

    parameters['W' + str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
    parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))


  return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W, b):

  Z = np.dot(W.T, A_prev) + b

  return Z

# %%
# Forward Prop
def L_layer_forward(X, parameters):

  A = X
  L = len(parameters) // 2

  for l in range(1, L+1):
    A_prev = A
    Wl = parameters['W' + str(l)]
    bl = parameters['b' + str(l)]
    print("A"+str(l-1)+": ", A_prev)
    print("W"+str(l)+": ", Wl)
    print("b"+str(l)+": ", bl)
    print("--"*20)

    A = linear_forward(A_prev, Wl, bl)
    print("A"+str(l)+": ", A)
    print("**"*20)

  return A,A_prev

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X, parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************

# %%
y_hat = y_hat[0][0]

# %%
A1
# Out:
# array([[1.6],
#        [1.6]])

# %%
update_parameters(parameters,y,y_hat,A1,X)
# Out:
# /tmp/ipykernel_16454/332058445.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
# /tmp/ipykernel_16454/332058445.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
# /tmp/ipykernel_16454/332058445.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))
# /tmp/ipykernel_16454/332058445.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
# /tmp/ipykernel_16454/332058445.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
# /tmp/ipykernel_16454/332058445.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])
# /tmp/ipykernel_16454/332058445.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
# /tmp/ipykernel_16454/332058445.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
# /tmp/ipykernel_16454/332058445.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
parameters
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
X = df[['cgpa', 'profile_score']].values[3].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[3][0]

y_hat,A1 = L_layer_forward(X, parameters)
# Out:
# A0:  [[ 5]
#  [12]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.7]
#  [1.7]]
# ****************************************
# A1:  [[1.7]
#  [1.7]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.34]]
# ****************************************

# %%
update_parameters(parameters,y,y_hat,A1,X)
# Out:
# /tmp/ipykernel_16454/332058445.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
# /tmp/ipykernel_16454/332058445.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
# /tmp/ipykernel_16454/332058445.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))
# /tmp/ipykernel_16454/332058445.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
# /tmp/ipykernel_16454/332058445.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
# /tmp/ipykernel_16454/332058445.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])
# /tmp/ipykernel_16454/332058445.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
# /tmp/ipykernel_16454/332058445.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
# /tmp/ipykernel_16454/332058445.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
parameters
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def update_parameters(parameters,y,y_hat,A1,X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
X = df[['cgpa', 'profile_score']].values[1].reshape(2,1) # Shape(no of features, no. of training exaplme)
y = df[['lpa']].values[1][0]

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# ****************************************
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776]
#  [0.111776]]
# b2:  [[0.119136]]
# ----------------------------------------
# A2:  [[0.50054357]]
# ****************************************
# {'W1': array([[0.11458955, 0.1168776 ],
#         [0.11458955, 0.1168776 ]]),
#  'b1': array([[0.0019667],
#         [0.0019667]]),
#  'W2': array([[0.12712927],
#         [0.12712927]]),
#  'b2': array([[0.13612818]])}

# %%
X = df[['cgpa', 'profile_score']].values[2].reshape(2,1) # Shape(no of features, no. of training exaplme)
y = df[['lpa']].values[2][0]

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11458955 0.1168776 ]
#  [0.11458955 0.1168776 ]]
# b1:  [[0.0019667]
#  [0.0019667]]
# ----------------------------------------
# A1:  [[1.83539945]
#  [1.87200826]]
# ****************************************
# A1:  [[1.83539945]
#  [1.87200826]]
# W2:  [[0.12712927]
#  [0.12712927]]
# b2:  [[0.13612818]]
# ----------------------------------------
# A2:  [[0.6074482]]
# ****************************************
# {'W1': array([[0.12409711, 0.13272353],
#         [0.12412266, 0.13276611]]),
#  'b1': array([[0.00355129],
#         [0.00355555]]),
#  'W2': array([[0.14692424],
#         [0.14731907]]),
#  'b2': array([[0.15810417]])}

# %%
X = df[['cgpa', 'profile_score']].values[3].reshape(2,1) # Shape(no of features, no. of training exaplme)
y = df[['lpa']].values[3][0]

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[ 5]
#  [12]]
# W1:  [[0.12409711 0.13272353]
#  [0.12412266 0.13276611]]
# b1:  [[0.00355129]
#  [0.00355555]]
# ----------------------------------------
# A1:  [[2.11350869]
#  [2.26036654]]
# ****************************************
# A1:  [[2.11350869]
#  [2.26036654]]
# W2:  [[0.14692424]
#  [0.14731907]]
# b2:  [[0.15810417]]
# ----------------------------------------
# A2:  [[0.80162493]]
# ****************************************
# {'W1': array([[0.13482804, 0.15847776],
#         [0.1349909 , 0.15884991]]),
#  'b1': array([[0.00569748],
#         [0.0057292 ]]),
#  'W2': array([[0.17312488],
#         [0.17534027]]),
#  'b2': array([[0.18773702]])}

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 5

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['lpa']].values[j][0]

    # Parameter initialization


    y_hat,A1 = L_layer_forward(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append((y-y_hat)**2)

  print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# ****************************************
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776]
#  [0.111776]]
# b2:  [[0.119136]]
# ----------------------------------------
# A2:  [[0.50054357]]
# ****************************************
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11458955 0.1168776 ]
#  [0.11458955 0.1168776 ]]
# b1:  [[0.0019667]
#  [0.0019667]]
# ----------------------------------------
# A1:  [[1.83539945]
#  [1.87200826]]
# ****************************************
# A1:  [[1.83539945]
#  [1.87200826]]
# W2:  [[0.12712927]
#  [0.12712927]]
# b2:  [[0.13612818]]
# ----------------------------------------
# A2:  [[0.6074482]]
# ****************************************
# A0:  [[ 5]
#  [12]]
# W1:  [[0.12409711 0.13272353]
#  [0.12412266 0.13276611]]
# b1:  [[0.00355129]
#  [0.00355555]]
# ----------------------------------------
# A1:  [[2.11350869]
#  [2.26036654]]
# ****************************************
# A1:  [[2.11350869]
#  [2.26036654]]
# W2:  [[0.14692424]
#  [0.14731907]]
# b2:  [[0.15810417]]
# ----------------------------------------
# A2:  [[0.80162493]]
# ****************************************
# Epoch -  1 Loss -  25.321744156025517
# A0:  [[8]
#  [8]]
# W1:  [[0.13482804 0.15847776]
#  [0.1349909  0.15884991]]
# b1:  [[0.00569748]
#  [0.0057292 ]]
# ----------------------------------------
# A1:  [[2.16424899]
#  [2.54435052]]
# ****************************************
# A1:  [[2.16424899]
#  [2.54435052]]
# W2:  [[0.17312488]
#  [0.17534027]]
# b2:  [[0.18773702]]
# ----------------------------------------
# A2:  [[1.00854947]]
# ****************************************
# A0:  [[7]
#  [9]]
# W1:  [[0.1437341  0.16738383]
#  [0.14411185 0.16797086]]
# b1:  [[0.00681073]
#  [0.00686932]]
# ----------------------------------------
# A1:  [[2.30995614]
#  [2.69029382]]
# ****************************************
# A1:  [[2.30995614]
#  [2.69029382]]
# W2:  [[0.18607337]
#  [0.19056287]]
# b2:  [[0.19654577]]
# ----------------------------------------
# A2:  [[1.13903718]]
# ****************************************
# A0:  [[ 6]
#  [10]]
# W1:  [[0.15475619 0.18155508]
#  [0.15553536 0.18265822]]
# b1:  [[0.00838532]
#  [0.00850125]]
# ----------------------------------------
# A1:  [[2.49227603]
#  [2.92441391]]
# ****************************************
# A1:  [[2.49227603]
#  [2.92441391]]
# W2:  [[0.20391068]
#  [0.21133712]]
# b2:  [[0.21905904]]
# ----------------------------------------
# A2:  [[1.34529793]]
# ****************************************
# A0:  [[ 5]
#  [12]]
# W1:  [[0.16744187 0.20269788]
#  [0.16886056 0.20486689]]
# b1:  [[0.0104996 ]
#  [0.01072211]]
# ----------------------------------------
# A1:  [[2.87403566]
#  [3.48261418]]
# ****************************************
# A1:  [[2.87403566]
#  [3.48261418]]
# W2:  [[0.22711228]
#  [0.23856167]]
# b2:  [[0.24787107]]
# ----------------------------------------
# A2:  [[1.73141811]]
# ****************************************
# Epoch -  2 Loss -  18.320004165722047
# A0:  [[8]
#  [8]]
# W1:  [[0.18100301 0.23524462]
#  [0.18336278 0.23967222]]
# b1:  [[0.01321183]
#  [0.01362256]]
# ----------------------------------------
# A1:  [[2.92813816]
#  [3.8129573 ]]
# ****************************************
# A1:  [[2.92813816]
#  [3.8129573 ]]
# W2:  [[0.25739647]
#  [0.27525854]]
# b2:  [[0.28579571]]
# ----------------------------------------
# A2:  [[2.08903719]]
# ****************************************
# A0:  [[7]
#  [9]]
# W1:  [[0.18921518 0.24345679]
#  [0.1922245  0.24853394]]
# b1:  [[0.01423835]
#  [0.01473027]]
# ----------------------------------------
# A1:  [[3.06876509]
#  [3.95573325]]
# ****************************************
# A1:  [[3.06876509]
#  [3.95573325]]
# W2:  [[0.26858759]
#  [0.28983138]]
# b2:  [[0.29365331]]
# ----------------------------------------
# A2:  [[2.26438116]]
# ****************************************
# A0:  [[ 6]
#  [10]]
# W1:  [[0.20014476 0.25750911]
#  [0.20415354 0.26387128]]
# b1:  [[0.01579972]
#  [0.01643442]]
# ----------------------------------------
# A1:  [[3.25820367]
#  [4.20020184]]
# ****************************************
# A1:  [[3.25820367]
#  [4.20020184]]
# W2:  [[0.28537753]
#  [0.31147414]]
# b2:  [[0.31694538]]
# ----------------------------------------
# A2:  [[2.55501776]]
# ****************************************
# A0:  [[ 5]
#  [12]]
# W1:  [[0.21287024 0.27871824]
#  [0.21822616 0.28732564]]
# b1:  [[0.01792063]
#  [0.01877986]]
# ----------------------------------------
# A1:  [[3.7009857 ]
#  [4.86027872]]
# ****************************************
# A1:  [[3.7009857 ]
#  [4.86027872]]
# W2:  [[0.30782644]
#  [0.34041338]]
# b2:  [[0.34730334]]
# ----------------------------------------
# A2:  [[3.14106851]]
# ****************************************
# Epoch -  3 Loss -  9.473661050729628
# A0:  [[8]
#  [8]]
# W1:  [[0.22585131 0.3098728 ]
#  [0.23281    0.32232686]]
# b1:  [[0.02051684]
#  [0.02169662]]
# ----------------------------------------
# A1:  [[3.68980727]
#  [5.07929387]]
# ****************************************
# A1:  [[3.68980727]
#  [5.07929387]]
# W2:  [[0.33639014]
#  [0.37792434]]
# b2:  [[0.38564221]]
# ----------------------------------------
# A2:  [[3.54644581]]
# ****************************************
# A0:  [[7]
#  [9]]
# W1:  [[0.22831673 0.31233823]
#  [0.23558598 0.32510284]]
# b1:  [[0.02082502]
#  [0.02204362]]
# ----------------------------------------
# A1:  [[3.73931597]
#  [5.13433676]]
# ****************************************
# A1:  [[3.73931597]
#  [5.13433676]]
# W2:  [[0.3397372 ]
#  [0.38253181]]
# b2:  [[0.38343892]]
# ----------------------------------------
# A2:  [[3.61787081]]
# ****************************************
# A0:  [[ 6]
#  [10]]
# W1:  [[0.23509059 0.32104747]
#  [0.24326252 0.33497268]]
# b1:  [[0.02179271]
#  [0.02314027]]
# ----------------------------------------
# A1:  [[3.86496148]
#  [5.2991519 ]]
# ****************************************
# A1:  [[3.86496148]
#  [5.2991519 ]]
# W2:  [[0.35007363]
#  [0.39672445]]
# b2:  [[0.39948871]]
# ----------------------------------------
# A2:  [[3.85481293]]
# ****************************************
# A0:  [[ 5]
#  [12]]
# W1:  [[0.24452913 0.33677838]
#  [0.25406036 0.35296907]]
# b1:  [[0.02336581]
#  [0.02493991]]
# ----------------------------------------
# A1:  [[4.29473577]
#  [5.94446068]]
# ****************************************
# A1:  [[4.29473577]
#  [5.94446068]]
# W2:  [[0.36665576]
#  [0.41945979]]
# b2:  [[0.42375017]]
# ----------------------------------------
# A2:  [[4.49190204]]
# ****************************************
# Epoch -  4 Loss -  3.2520938634031613
# A0:  [[8]
#  [8]]
# W1:  [[0.25426555 0.36014576]
#  [0.2653287  0.38001309]]
# b1:  [[0.02531309]
#  [0.02719358]]
# ----------------------------------------
# A1:  [[4.18206705]
#  [5.94846444]]
# ****************************************
# A1:  [[4.18206705]
#  [5.94846444]]
# W2:  [[0.388199  ]
#  [0.44927837]]
# b2:  [[0.45429457]]
# ----------------------------------------
# A2:  [[4.75028523]]
# ****************************************
# A0:  [[7]
#  [9]]
# W1:  [[0.24968072 0.35556094]
#  [0.26004246 0.37472686]]
# b1:  [[0.02473998]
#  [0.0265328 ]]
# ----------------------------------------
# A1:  [[4.11288719]
#  [5.88800108]]
# ****************************************
# A1:  [[4.11288719]
#  [5.88800108]]
# W2:  [[0.38192351]
#  [0.44035228]]
# b2:  [[0.43885171]]
# ----------------------------------------
# A2:  [[4.60245475]]
# ****************************************
# A0:  [[ 6]
#  [10]]
# W1:  [[0.25182457 0.35831731]
#  [0.26251936 0.37791144]]
# b1:  [[0.02504625]
#  [0.02688664]]
# ----------------------------------------
# A1:  [[4.16118723]
#  [5.95590488]]
# ****************************************
# A1:  [[4.16118723]
#  [5.95590488]]
# W2:  [[0.38519363]
#  [0.44503378]]
# b2:  [[0.44582887]]
# ----------------------------------------
# A2:  [[4.69927052]]
# ****************************************
# A0:  [[ 5]
#  [12]]
# W1:  [[0.25800593 0.36861958]
#  [0.26970762 0.38989188]]
# b1:  [[0.02607647]
#  [0.02808469]]
# ----------------------------------------
# A1:  [[4.55259758]
#  [6.54988512]]
# ****************************************
# A1:  [[4.55259758]
#  [6.54988512]]
# W2:  [[0.39601879]
#  [0.46052782]]
# b2:  [[0.46312928]]
# ----------------------------------------
# A2:  [[5.28244776]]
# ****************************************
# Epoch -  5 Loss -  1.3407132589299962
# {'W1': array([[0.26507636, 0.38558861],
#         [0.27800387, 0.40980287]]),
#  'b1': array([[0.02749056],
#         [0.02974394]]),
#  'W2': array([[0.41165744],
#         [0.48302736]]),
#  'b2': array([[0.48646246]])}
