# %%
import math
def sigmoid(x):
    return 1 / (1 + math.exp(-x))
sigmoid(1)
# Out:
# 0.7310585786300049

# %%
sigmoid(10)
# Out:
# 0.9999546021312976

# %%
sigmoid(100)
# Out:
# 1.0

# %%
sigmoid(-1)
# Out:
# 0.2689414213699951

# %%
sigmoid(-10)
# Out:
# 4.5397868702434395e-05

# %%
sigmoid(-100)
# Out:
# 3.7200759760208356e-44
