# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pmgho'

# %%
os.chdir('C:\\Users\\pmgho\\OneDrive\\Desktop\\Prajwal_capstone_sql_project')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pmgho\\OneDrive\\Desktop\\Prajwal_capstone_sql_project'

# %%
df = pd.read_csv('Admission_Predict.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (400, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Serial No.'],inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
X = df.iloc[:,0:-1].values
y = df.iloc[:,-1].values

# %%
X
# Out:
# array([[337.  , 118.  ,   4.  , ...,   4.5 ,   9.65,   1.  ],
#        [324.  , 107.  ,   4.  , ...,   4.5 ,   8.87,   1.  ],
#        [316.  , 104.  ,   3.  , ...,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [330.  , 116.  ,   4.  , ...,   4.5 ,   9.45,   1.  ],
#        [312.  , 103.  ,   3.  , ...,   4.  ,   8.78,   0.  ],
#        [333.  , 117.  ,   4.  , ...,   4.  ,   9.66,   1.  ]])

# %%
y
# Out:
# array([0.92, 0.76, 0.72, 0.8 , 0.65, 0.9 , 0.75, 0.68, 0.5 , 0.45, 0.52,
#        0.84, 0.78, 0.62, 0.61, 0.54, 0.66, 0.65, 0.63, 0.62, 0.64, 0.7 ,
#        0.94, 0.95, 0.97, 0.94, 0.76, 0.44, 0.46, 0.54, 0.65, 0.74, 0.91,
#        0.9 , 0.94, 0.88, 0.64, 0.58, 0.52, 0.48, 0.46, 0.49, 0.53, 0.87,
#        0.91, 0.88, 0.86, 0.89, 0.82, 0.78, 0.76, 0.56, 0.78, 0.72, 0.7 ,
#        0.64, 0.64, 0.46, 0.36, 0.42, 0.48, 0.47, 0.54, 0.56, 0.52, 0.55,
#        0.61, 0.57, 0.68, 0.78, 0.94, 0.96, 0.93, 0.84, 0.74, 0.72, 0.74,
#        0.64, 0.44, 0.46, 0.5 , 0.96, 0.92, 0.92, 0.94, 0.76, 0.72, 0.66,
#        0.64, 0.74, 0.64, 0.38, 0.34, 0.44, 0.36, 0.42, 0.48, 0.86, 0.9 ,
#        0.79, 0.71, 0.64, 0.62, 0.57, 0.74, 0.69, 0.87, 0.91, 0.93, 0.68,
#        0.61, 0.69, 0.62, 0.72, 0.59, 0.66, 0.56, 0.45, 0.47, 0.71, 0.94,
#        0.94, 0.57, 0.61, 0.57, 0.64, 0.85, 0.78, 0.84, 0.92, 0.96, 0.77,
#        0.71, 0.79, 0.89, 0.82, 0.76, 0.71, 0.8 , 0.78, 0.84, 0.9 , 0.92,
#        0.97, 0.8 , 0.81, 0.75, 0.83, 0.96, 0.79, 0.93, 0.94, 0.86, 0.79,
#        0.8 , 0.77, 0.7 , 0.65, 0.61, 0.52, 0.57, 0.53, 0.67, 0.68, 0.81,
#        0.78, 0.65, 0.64, 0.64, 0.65, 0.68, 0.89, 0.86, 0.89, 0.87, 0.85,
#        0.9 , 0.82, 0.72, 0.73, 0.71, 0.71, 0.68, 0.75, 0.72, 0.89, 0.84,
#        0.93, 0.93, 0.88, 0.9 , 0.87, 0.86, 0.94, 0.77, 0.78, 0.73, 0.73,
#        0.7 , 0.72, 0.73, 0.72, 0.97, 0.97, 0.69, 0.57, 0.63, 0.66, 0.64,
#        0.68, 0.79, 0.82, 0.95, 0.96, 0.94, 0.93, 0.91, 0.85, 0.84, 0.74,
#        0.76, 0.75, 0.76, 0.71, 0.67, 0.61, 0.63, 0.64, 0.71, 0.82, 0.73,
#        0.74, 0.69, 0.64, 0.91, 0.88, 0.85, 0.86, 0.7 , 0.59, 0.6 , 0.65,
#        0.7 , 0.76, 0.63, 0.81, 0.72, 0.71, 0.8 , 0.77, 0.74, 0.7 , 0.71,
#        0.93, 0.85, 0.79, 0.76, 0.78, 0.77, 0.9 , 0.87, 0.71, 0.7 , 0.7 ,
#        0.75, 0.71, 0.72, 0.73, 0.83, 0.77, 0.72, 0.54, 0.49, 0.52, 0.58,
#        0.78, 0.89, 0.7 , 0.66, 0.67, 0.68, 0.8 , 0.81, 0.8 , 0.94, 0.93,
#        0.92, 0.89, 0.82, 0.79, 0.58, 0.56, 0.56, 0.64, 0.61, 0.68, 0.76,
#        0.86, 0.9 , 0.71, 0.62, 0.66, 0.65, 0.73, 0.62, 0.74, 0.79, 0.8 ,
#        0.69, 0.7 , 0.76, 0.84, 0.78, 0.67, 0.66, 0.65, 0.54, 0.58, 0.79,
#        0.8 , 0.75, 0.73, 0.72, 0.62, 0.67, 0.81, 0.63, 0.69, 0.8 , 0.43,
#        0.8 , 0.73, 0.75, 0.71, 0.73, 0.83, 0.72, 0.94, 0.81, 0.81, 0.75,
#        0.79, 0.58, 0.59, 0.47, 0.49, 0.47, 0.42, 0.57, 0.62, 0.74, 0.73,
#        0.64, 0.63, 0.59, 0.73, 0.79, 0.68, 0.7 , 0.81, 0.85, 0.93, 0.91,
#        0.69, 0.77, 0.86, 0.74, 0.57, 0.51, 0.67, 0.72, 0.89, 0.95, 0.79,
#        0.39, 0.38, 0.34, 0.47, 0.56, 0.71, 0.78, 0.73, 0.82, 0.62, 0.96,
#        0.96, 0.46, 0.53, 0.49, 0.76, 0.64, 0.71, 0.84, 0.77, 0.89, 0.82,
#        0.84, 0.91, 0.67, 0.95])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (320, 7)
# (80, 7)
# (320,)
# (80,)

# %%
X_train
# Out:
# array([[301.  ,  97.  ,   2.  , ...,   3.  ,   7.88,   1.  ],
#        [334.  , 119.  ,   5.  , ...,   4.5 ,   9.7 ,   1.  ],
#        [305.  , 112.  ,   3.  , ...,   3.5 ,   8.65,   0.  ],
#        ...,
#        [325.  , 107.  ,   3.  , ...,   3.5 ,   9.11,   1.  ],
#        [326.  , 111.  ,   5.  , ...,   4.  ,   9.23,   1.  ],
#        [300.  , 105.  ,   1.  , ...,   2.  ,   7.8 ,   0.  ]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.22      , 0.17857143, 0.25      , ..., 0.42857143, 0.25      ,
#         1.        ],
#        [0.88      , 0.96428571, 1.        , ..., 0.85714286, 0.91911765,
#         1.        ],
#        [0.3       , 0.71428571, 0.5       , ..., 0.57142857, 0.53308824,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.70220588,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.74632353,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.22058824,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras 
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(7,activation='relu'))
model.add(Dense(1,activation='linear'))
# Out:
# C:\Users\pmgho\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 7)                   │              56 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │              56 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │               8 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 120 (480.00 B)
#  Trainable params: 120 (480.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error',optimizer='Adam')

# %%
history=model.fit(X_train_scaled,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.5674 - val_loss: 0.5453
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4508 - val_loss: 0.4272
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3533 - val_loss: 0.3278
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2698 - val_loss: 0.2445
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2002 - val_loss: 0.1777
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1454 - val_loss: 0.1270
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1053 - val_loss: 0.0913
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0778 - val_loss: 0.0684
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0611 - val_loss: 0.0547
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0511 - val_loss: 0.0473
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0457 - val_loss: 0.0435
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0428 - val_loss: 0.0412
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0407 - val_loss: 0.0394
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0387 - val_loss: 0.0378
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0364 - val_loss: 0.0359
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0342 - val_loss: 0.0334
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0318 - val_loss: 0.0308
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0293 - val_loss: 0.0280
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0270 - val_loss: 0.0253
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0247 - val_loss: 0.0230
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0228 - val_loss: 0.0209
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0213 - val_loss: 0.0193
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0201 - val_loss: 0.0180
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0192 - val_loss: 0.0171
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0183 - val_loss: 0.0164
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0178 - val_loss: 0.0158
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0172 - val_loss: 0.0154
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0167 - val_loss: 0.0150
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0162 - val_loss: 0.0147
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0155 - val_loss: 0.0141
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0149 - val_loss: 0.0137
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0146 - val_loss: 0.0134
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0141 - val_loss: 0.0130
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0138 - val_loss: 0.0126
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0134 - val_loss: 0.0123
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0128 - val_loss: 0.0119
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0125 - val_loss: 0.0116
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0123 - val_loss: 0.0113
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0115 - val_loss: 0.0107
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0113 - val_loss: 0.0105
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0112 - val_loss: 0.0104
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0110 - val_loss: 0.0102
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0108 - val_loss: 0.0100
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0106 - val_loss: 0.0099
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0105 - val_loss: 0.0097
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0103 - val_loss: 0.0096
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0102 - val_loss: 0.0094
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0100 - val_loss: 0.0093
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0099 - val_loss: 0.0092
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0098 - val_loss: 0.0090
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0097 - val_loss: 0.0089
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0095 - val_loss: 0.0088
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0094 - val_loss: 0.0086
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0093 - val_loss: 0.0086
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0091 - val_loss: 0.0083
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0090 - val_loss: 0.0081
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0089 - val_loss: 0.0080
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0089 - val_loss: 0.0080
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0087 - val_loss: 0.0078
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0086 - val_loss: 0.0076
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0084 - val_loss: 0.0075
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0084 - val_loss: 0.0074
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0083 - val_loss: 0.0073
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0083 - val_loss: 0.0073
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0082 - val_loss: 0.0071
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0081 - val_loss: 0.0071
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0080 - val_loss: 0.0070
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0080 - val_loss: 0.0069
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0080 - val_loss: 0.0069
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0077 - val_loss: 0.0066
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0077 - val_loss: 0.0066
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0076 - val_loss: 0.0066
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0076 - val_loss: 0.0065
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0075 - val_loss: 0.0064
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0075 - val_loss: 0.0064
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0074 - val_loss: 0.0063
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0074 - val_loss: 0.0063
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0073 - val_loss: 0.0061
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0072 - val_loss: 0.0059
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0071 - val_loss: 0.0060
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0070 - val_loss: 0.0059
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0070 - val_loss: 0.0059
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0069 - val_loss: 0.0057

# %%
y_pred=model.predict(X_test_scaled)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
y_pred
# Out:
# array([[0.6704382 ],
#        [0.63899785],
#        [0.8412548 ],
#        [0.89273125],
#        [0.807022  ],
#        [0.6811075 ],
#        [0.64699006],
#        [0.54483473],
#        [0.55748945],
#        [0.8729407 ],
#        [0.829782  ],
#        [0.871157  ],
#        [0.9114611 ],
#        [0.6600162 ],
#        [0.7540082 ],
#        [0.68865746],
#        [0.74380296],
#        [0.90454423],
#        [0.6035116 ],
#        [0.6609041 ],
#        [0.6086769 ],
#        [0.7870739 ],
#        [0.82105434],
#        [0.8971366 ],
#        [0.75721437],
#        [0.57950723],
#        [0.7255995 ],
#        [0.6906732 ],
#        [0.8506619 ],
#        [0.7197793 ],
#        [0.9546901 ],
#        [0.59260803],
#        [0.85412174],
#        [0.75002706],
#        [0.76718736],
#        [0.7269829 ],
#        [0.59204715],
#        [0.6786012 ],
#        [0.8932961 ],
#        [0.65117365],
#        [0.8568963 ],
#        [0.66385144],
#        [0.95131755],
#        [0.65748554],
#        [0.9361729 ],
#        [0.7543565 ],
#        [0.7639873 ],
#        [0.8405094 ],
#        [0.62225896],
#        [0.608351  ],
#        [0.8003324 ],
#        [0.54192585],
#        [0.8246973 ],
#        [0.74572474],
#        [0.7070044 ],
#        [0.9477274 ],
#        [0.4390723 ],
#        [0.6497699 ],
#        [0.8826723 ],
#        [0.816285  ],
#        [0.873933  ],
#        [0.6758598 ],
#        [0.9053186 ],
#        [0.68391144],
#        [0.5317709 ],
#        [0.8443158 ],
#        [0.8446412 ],
#        [0.72309977],
#        [0.6517407 ],
#        [0.81893474],
#        [0.82687485],
#        [0.5938863 ],
#        [0.75960714],
#        [0.6028897 ],
#        [0.84448975],
#        [0.4384386 ],
#        [0.67280036],
#        [0.6660887 ],
#        [0.74926776],
#        [0.6134679 ]], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6775140183869369

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
